# %%
import xarray as xr
import numpy as np
import pandas as pd
from datetime import date
today = date.today()


import re

# %%
# Read the Excel file into a pandas DataFrame
data = pd.read_excel('MIRAMARE_CO2-sensor_final.xlsx', header=0)
             
                    
cols=['Year_YYYY','Month_MM','Day_DD']
data['date'] = data[cols].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")

cols=['Hour_hh','Min_mm','Sec_ss']
data['time'] = data[cols].apply(lambda x: ':'.join(x.values.astype(str)), axis="columns")


data['datetime'] = pd.to_datetime(data['date'] + ' ' + data['time'])


# Iterate over each column in the DataFrame
data.columns = [re.sub(r'[-%/]', '_', col) for col in data.columns]

for column in data.columns:
    # Convert the column to a NumPy array
    np_array = data[column].to_numpy()
    
    # Convert the data type to int32 or float32
    if np_array.dtype == 'int64':
        np_array = np_array.astype('int32')
    elif np_array.dtype == 'float64':
        np_array = np_array.astype('float32')
    
    # Delete the old NumPy array if it exists
    if column in locals():
        del locals()[column]
    
    # Use the modified column name as the variable name
    globals()[column] = np_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 35
#      32     # Use the modified column name as the variable name
#      33     globals()[column] = np_array
# ---> 35 whos
#
# NameError: name 'whos' is not defined

# %%
time_co=datetime
Lat_co=Latitude
Lon_co=Longitude

Pressure_co=Depth_dbar
Temperature_co=T_SBE_degC
Salinity_co=S_SBE

pCO2_co=pCO2_uatm

# %%
# Read the Excel file into a pandas DataFrame
data = pd.read_excel('MIRAMARE_Meteo.xlsx', header=1)
# Iterate over each column in the DataFrame
data.columns = [re.sub(r'[-%/]', '_', col) for col in data.columns]

for column in data.columns:
    # Convert the column to a NumPy array
    np_array = data[column].to_numpy()
    
    # Convert the data type to int32 or float32
    if np_array.dtype == 'int64':
        np_array = np_array.astype('int32')
    elif np_array.dtype == 'float64':
        np_array = np_array.astype('float32')
    
    # Delete the old NumPy array if it exists
    if column in locals():
        del locals()[column]
    
    # Use the modified column name as the variable name
    globals()[column] = np_array

# %%
time_meteo=Date_Time


Pressure_meteo=Pres_mbar
RH=RelHum__
Temperature_meteo=T_degC+273
Wind_Gust_Dir=WinDirGust_degree
Wind_Gust_Speed=WinSpeedGust_m_s
Wind_Speed=WinSpeed_m_s
Wind_Dir=WindDir_degree

# %%
# Read the Excel file into a pandas DataFrame
data = pd.read_excel('MIRAMARE_discrete.xlsx', header=0)
data['Datetime'] = pd.to_datetime(data['Date'].astype(str) + ' ' + data['UTC_time'].astype(str))
# Iterate over each column in the DataFrame

data.columns = [re.sub(r'[-%/]', '_', col) for col in data.columns]

for column in data.columns:
    # Convert the column to a NumPy array
    np_array = data[column].to_numpy()
    
    # Convert the data type to int32 or float32
    if np_array.dtype == 'int64':
        np_array = np_array.astype('int32')
    elif np_array.dtype == 'float64':
        np_array = np_array.astype('float32')
    
    # Delete the old NumPy array if it exists
    if column in locals():
        del locals()[column]
    
    # Use the modified column name as the variable name
    globals()[column] = np_array

# %%
time_d=Datetime

DO_d=DO_mL_L
Depth_d=Depth_m


Salinity_d=S_SBE19
Temperature_d=T_SBE19_degC


Si=Si_umol_kg
Alkalinity= TA_umol_kg
T_pH_d=T_at_pH_measurements
PO4=PO4_umol_kg

# %%
# Read the Excel file into a pandas DataFrame
data = pd.read_excel('MIRAMARE_SBE37ODO.xlsx', header=0)
# Iterate over each column in the DataFrame
data.columns = [re.sub(r'[-%/]', '_', col) for col in data.columns]

for column in data.columns:
    # Convert the column to a NumPy array
    np_array = data[column].to_numpy()
    
    # Convert the data type to int32 or float32
    if np_array.dtype == 'int64':
        np_array = np_array.astype('int32')
    elif np_array.dtype == 'float64':
        np_array = np_array.astype('float32')
    
    # Delete the old NumPy array if it exists
    if column in locals():
        del locals()[column]
    
    # Use the modified column name as the variable name
    globals()[column] = np_array

# %%
time_ctd=Date_Time

Lat=Latitude
Lon=Longitude



Temperature_ctd=T_SBE_degC
Salinity_ctd=S_SBE
DO_ctd=DO_mL_L

# %%
ds=xr.Dataset(
    data_vars=dict(
      
        Pressure_co=(["time_co"], Pressure_co,{"units": "dbar",
                                            "standard_name": "sea_water_pressure_due_to_sea_water",
                                            "short_name": "SW_pressure",
                                            "long_name": "Sea_water_pressure",
                                            "description": "Sea water pressure is the pressure that exists in the medium of sea water. It includes the pressure due to overlying sea water, sea ice, air and any other medium that may be present. ",
                                            "valid_min": "0",
                                            "valid_max": "6500",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        
        
        Temperature_co=(["time_co"], Temperature_co,{"units": "degree Celcius",
                                            "standard_name": "sea_water_temperature",
                                            "short_name": "SW_Temperature",
                                            "long_name": "Sea Water Temperature",
                                            "description": "Sea water temperature is the in situ temperature of the sea water",
                                            "valid_min": "-10",
                                            "valid_max": "100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        
        Salinity_co=(["time_co"], Salinity_co,{"units": "psu",
                                            "standard_name": "sea_water_salinity",
                                            "short_name": "so",
                                            "long_name": "Sea Water Salinity",
                                            "description": "Sea water salinity is the salt content of sea water on the Practical Salinity Scale of 1978",
                                            "valid_min": "0",
                                            "valid_max": "100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        pCO2_co=(["time_co"], pCO2_co,{"units": "uatm",
                                            "standard_name": "surface_partial_pressure_of_carbon_dioxide_in_sea_water",
                                            "short_name": "pCO2",
                                            "long_name": "Surface partial pressure of carbon dioxide in sea water",
                                            "description": "pCO2 in water logged by the Pro-Oceanus sensor",
                                            "valid_min": "0",
                                            "valid_max": "400",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        air_pressure=(["time_meteo"], Pressure_meteo,{"units": "mbar",
                                            "standard_name": "air_pressure",
                                            "short_name": "air_pressure",
                                            "long_name": "Air_pressure",
                                            "description": "Air pressure is the force per unit area which would be exerted when the moving gas molecules of which the air is composed strike a theoretical surface of any orientation.",
                                            "valid_min": "800",
                                            "valid_max": "1100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        rel_humidity=(["time_meteo"], RH,{"units": "%",
                                            "standard_name": "relative_humidity",
                                            "short_name": "rel_humidity",
                                            "long_name": "Relative_humidity",
                                            "description": "Air pressure is the force per unit area which would be exerted when the moving gas molecules of which the air is composed strike a theoretical surface of any orientation.",
                                            "valid_min": "800",
                                            "valid_max": "1100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        Temperature_meteo=(["time_meteo"], Temperature_meteo,{"units": "K",
                                            "standard_name": "air_temperature",
                                            "short_name": "Temp",
                                            "long_name": "Temperature",
                                            "description": "Air temperature is the bulk temperature of the air",
                                            "valid_min": "-273",
                                            "valid_max": "500",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        
        Wind_Gust_Dir=(["time_meteo"], Wind_Gust_Dir,{"units": "degrees",
                                            "standard_name": "gust_direction",
                                            "short_name": "gust_dir",
                                            "long_name": "Wind Gust Direction",
                                            "description": "Direction of a gust.",
                                            "valid_min": "0",
                                            "valid_max": "3600",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        Wind_Gust_Speed=(["time_meteo"], Wind_Gust_Speed,{"units": "m/s",
                                            "standard_name": "gust_speed",
                                            "short_name": "gust",
                                            "long_name": "Wind Gust Speed",
                                            "description": "A gust is a sudden brief period of high wind speed. In an observed timeseries of wind speed, the gust wind speed can be indicated by a cell_methods of maximum for the time-interval.",
                                            "valid_min": "0",
                                            "valid_max": "400",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        Wind_Dir=(["time_meteo"], Wind_Dir,{"units": "degrees",
                                            "standard_name": "wind_direction",
                                            "short_name": "wdir",
                                            "long_name": "Wind_Direction", 
                                            "description": "the direction of the wind vector is usually (but not always) given as the direction from which it is blowing(westerly, northerly, etc.)",
                                            "valid_min": "0",
                                            "valid_max": "360",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        Wind_Speed=(["time_meteo"], Wind_Speed,{"units": "m/s",
                                            "standard_name": "wind_speed",
                                            "short_name": "wspd",
                                            "long_name": "Wind Speed",
                                            "description": "The wind speed is the magnitude of the wind velocity",
                                            "valid_min": "0",
                                            "valid_max": "400",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        Oxygen_d=(["time_d"], DO_d,{"units": "uatm",
                                            "standard_name": "mole_concentration_of_dissolved_molecular_oxygen_in_sea_water",
                                            "short_name": "DO",
                                            "long_name": "mole_concentration_of_dissolved_molecular_oxygen_in_sea_water",
                                            "description": "Molarity of dissolved Oxygen in sea water measured by SBE37DO",
                                            "valid_min": "0",
                                            "valid_max": "400",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        Depth_d=(["time_d"], Depth_d,{"units": "m",
                                            "standard_name": "depth",
                                            "short_name": "depth",
                                            "long_name": "depth",
                                            "description": "depth from where the water sample is collected (m)",
                                            "valid_min": "0",
                                            "valid_max": "10000",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        Phosphate=(["time_d"],PO4,{"units": "umol/kg",
                                            "standard_name": "mole_concentration_of_phosphate_in_sea_water",
                                            "short_name": "PO4",
                                            "long_name": "mole_concentration_of_phosphate_in_sea_water",
                                            "description": "Molarity of dissolved Phosphate in sea water measured at discrete stations.",
                                            "valid_min": "0",
                                            "valid_max": "10000",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        Salinity_d=(["time_d"], Salinity_d,{"units": "psu",
                                            "standard_name": "sea_water_salinity",
                                            "short_name": "so",
                                            "long_name": "Sea Water Salinity",
                                            "description": "Sea water salinity is the salt content of sea water on the Practical Salinity Scale of 1978",
                                            "valid_min": "0",
                                            "valid_max": "100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        Silicate=(["time_d"], Si,{"units": "umol/kg",
                                            "standard_name": "mole_concentration_of_silicate_in_sea_water",
                                            "short_name": "SI",
                                            "long_name": "mole_concentration_of_silicate_in_sea_water",
                                            "description": "Molarity of dissolved Silicate in sea water measured at discrete stations.",
                                            "valid_min": "0",
                                            "valid_max": "100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        Alkalinity=(["time_d"],Alkalinity,{"units": "umol/kg",
                                            "standard_name":  "sea_water_total_alkalinity",
                                            "short_name": "alkalinity",
                                            "long_name": "Sea Water Total Alkalinity",
                                            "description": "Total alkalinity sea water measured at discrete stations.",
                                            "valid_min": "0",
                                            "valid_max": "100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
                

        
        Temperature_d=(["time_d"], Temperature_d,{"units": "degree Celcius",
                                            "standard_name": "sea_water_temperature",
                                            "short_name": "SW_Temperature",
                                            "long_name": "Sea Water Temperature",
                                            "description": "Sea water temperature is the in situ temperature of the sea water",
                                            "valid_min": "-10",
                                            "valid_max": "100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        T_pH_d=(["time_d"], T_pH_d,{"units": "degree Celcius",
                                            "standard_name": "sea_water_temperature_during_pH_measurement",
                                            "short_name": "TpH",
                                            "long_name": "Sea Water Temperature during pH measurement",
                                            "description": "temperature of the water during pH measurements",
                                            "valid_min": "-10",
                                            "valid_max": "100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        Temperature_SBE37=(["time_ctd"], Temperature_ctd,{"units": "degree Celcius",
                                            "standard_name": "sea_water_temperature",
                                            "short_name": "SW_Temperature",
                                            "long_name": "Sea Water Temperature",
                                            "description": "Sea water temperature is the in situ temperature of the sea water",
                                            "valid_min": "-10",
                                            "valid_max": "100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        
        Salinity_SBE37=(["time_ctd"], Salinity_ctd,{"units": "psu",
                                            "standard_name": "sea_water_salinity",
                                            "short_name": "so",
                                            "long_name": "Sea Water Salinity",
                                            "description": "Sea water salinity is the salt content of sea water on the Practical Salinity Scale of 1978",
                                            "valid_min": "0",
                                            "valid_max": "100",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),
        
        
        Oxygen_SBE37=(["time_ctd"], DO_ctd,{"units": "uatm",
                                            "standard_name": "mole_concentration_of_dissolved_molecular_oxygen_in_sea_water",
                                            "short_name": "DO",
                                            "long_name": "mole_concentration_of_dissolved_molecular_oxygen_in_sea_water",
                                            "description": "Molarity of dissolved Oxygen in sea water measured by SBE37DO",
                                            "valid_min": "0",
                                            "valid_max": "400",
                                            "missing_value": "-9999999",
                                            "axis": "time",
                                            "history": ""}),

        
    ),
    coords=dict(
    lon=(["lon"], Lon_co,{"units": "degrees East",
                                        "standard_name": "longitude",
                                        "short_name": "lon",
                                        "long_name": "Longitude",
                                        "description": "The Longitude represents the degrees east",
                                        "valid_min": "0",
                                        "valid_max": "360",
                                        "missing_value": "-9999999",
                                        "history": ""}),
                       
    lat=(["lat"], Lat_co,{"units": "degrees North",
                                        "standard_name": "latitude",
                                        "short_name": "lat",
                                        "long_name": "Latitude",
                                        "description": "The latitude represents the degrees north",
                                        "valid_min": "-90",
                                        "valid_max": "90",
                                        "missing_value": "-9999999",
                                        "history": ""}),
    time=time_co,
    time_meteo=time_meteo,
    time_d=time_d,
    time_ctd=time_ctd,
    reference_time=time[0],
)
)

# %%
ds.attrs['id']='DOI needed'

ds.attrs['naming_authority']='Istituto Nazionale di Oceanografia e Geofisica Sperimentale (OGS), Trieste, Italy '

ds.attrs['title'] = "MIRAMARE_SBE37"

ds.attrs['summary']='The ATL2MED demonstration experiment took place in the North-East Atlantic between October 2019 and July 2020.During this time, two Salidrone vessels equipped with scientific instruments sailed from the North-East Atlantic Ocean to the Gulf of Trieste in the Mediterranean Sea. A number of fixed stations also took part in the experiment, e.g., DYFAMED, W1M3A, E2M3A, PALOMA, and MIRAMARE, which all were visited by the Saildorne vessels.'

ds.attrs['keywords']='Hydrography'
ds.attrs['keywords_vocabulary']='Temperature, Salinity, DO'

ds.attrs['geospatial_lat_min']=np.min(Lat)
ds.attrs['geospatial_lat_max']=np.max(Lat)
ds.attrs['geospatial_lon_miN']=np.min(Lon)
ds.attrs['geospatial_lon_max']=np.max(Lon)

ds.attrs['time_coverage_start']=str(np.min(time))
ds.attrs['time_coverage_end']=str(np.max(time))

ds.attrs['Conventions']='CF 1.11'

ds.attrs['processing_level']='LEVEL 2'

ds.attrs['date_created']=str(today)

ds.attrs['creator_type']='Group'
ds.attrs['creator_institution']='Geophysical Institute'
ds.attrs['creator_name']='Joan Mateu Horrach Pou'
ds.attrs['creator_email']='joan.pou@uib.no'
ds.attrs['creator_url']=''

ds.attrs['institution']='Geophysical Institute'

ds.attrs['publisher_name']='Joan Mateu Horrach Pou'
ds.attrs['publisher_email']='joan.pou@uib.no'
ds.attrs['publisher_url']='I need the url'

ds.attrs['project']='ICOS'

ds.attrs['platform']='MIRAMARE'
ds.attrs['platform_vocabulary']='MIRAMARE_SBE37ODO'

ds.attrs['instrument']='SBE37ODO'


ds.attrs['iso_topic_category']='Needed'
ds.attrs['activity_type']='in situ observation'
ds.attrs['operational_status']='active'

# %%
comp = dict(zlib=True, complevel=5)
encoding = {var: comp for var in ds.data_vars}
ds.to_netcdf('MIRAMARE_all.nc', encoding=encoding)
